# %%
import torch
import random
import json
from torch import nn
import cv2
import string as STR
import matplotlib.pyplot as plt

# %%
import importlib

import BaseTextDetectorModel
importlib.reload(BaseTextDetectorModel)
# Out:
# <module 'BaseTextDetectorModel' from '/Users/tnluser/PERSONAL/bb/notebooks/BaseTextDetectorModel.py'>

# %%
dataset = BaseTextDetectorModel.ImageTextDataset(10)

# %%
dataset[0][0].shape
# Out:
# torch.Size([1, 32, 128])

# %%
letters = STR.ascii_letters + STR.digits
letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %%
letters[5]
# Out:
# 'f'

# %%
dataset[0][1]
# Out:
# tensor([54, 60, 55, 54, 55, 54, 60, 58,  1,  1])

# %%
from BaseTextDetectorModel import BaseTextDetector

# %%
model = torch.load('BaseTextDetector.pt',map_location=torch.device('cpu')).eval()

# %%
for i in range(len(dataset)):
    data = dataset[i]
    plt.imshow(data[0].transpose(0, 2).transpose(0, 1))
    plt.show()
    print(data[0].mean(), data[0].std())
    print(data[1])
    print(data[2])
    print(BaseTextDetectorModel.model_text(data[1]))
    model_out, _ = model(data[0][None, ...])
    model_out = model_out.squeeze().detach()
    model_text = BaseTextDetectorModel.model_text(model_out.detach(), max_needed=True)
    print(BaseTextDetectorModel.model_out_to_text(model_text))
# Out:
# tensor(0.0552) tensor(0.2284)
# tensor([19,  6,  3, 61, 55, 21,  2,  3, 13, 55])
# 10
# reb71tabl1
# reb71tabl1
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# tensor(0.0222) tensor(0.1474)
# tensor([16, 22, 19, 10, 55,  1,  1,  1,  1,  1])
# 5
# ouri1
# ouri1
# tensor(0.0696) tensor(0.2545)
# tensor([56, 62, 55, 60, 63, 60, 59, 55, 57,  1])
# 9
# 281696513
# 281696513
# tensor(0.0544) tensor(0.2269)
# tensor([ 5, 16, 55, 14, 16, 63, 20,  6,  1,  1])
# 8
# do1mo9se
# do1mo9se
# tensor(0.0640) tensor(0.2447)
# tensor([32, 42, 53, 42, 42, 41, 28, 39,  1,  1])
# 8
# EOZOONAL
# EOZOONAL
# tensor(0.0491) tensor(0.2160)
# tensor([58,  2, 20, 20, 62, 16, 15,  1,  1,  1])
# 7
# 4ass8on
# 4ass8on
# tensor(0.0488) tensor(0.2155)
# tensor([55, 54,  6, 23, 59,  2, 15, 21,  1,  1])
# 8
# 10ev5ant
# 10ev5ant
# tensor(0.0452) tensor(0.2077)
# tensor([63, 61, 62, 55, 54, 58,  1,  1,  1,  1])
# 6
# 978104
# 978104
# tensor(0.0388) tensor(0.1932)
# tensor([59, 62, 58, 55, 58,  1,  1,  1,  1,  1])
# 5
# 58414
# 58414
# tensor(0.0610) tensor(0.2394)
# tensor([ 9, 26, 17, 59, 21,  2, 25, 63, 54,  1])
# 9
# hyp5tax90
# hyp5tax90

# %%
BaseTextDetectorModel.export_onnx('BaseTextDetector.pt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cn/9kqyl3fn4dxdrx0sql6q9vlm0000gp/T/ipykernel_19005/464676190.py in <module>
# ----> 1 BaseTextDetectorModel.export_onnx('BaseTextDetector.pt')
#
# ~/PERSONAL/bb/notebooks/BaseTextDetectorModel.py in export_onnx(model_path)
#     206     input_names = ['input']
#     207     output_names = ['output', 'loss']
# --> 208     torch.onnx.export(model, dummy_input, "BaseTextDetector.onnx", verbose=True,
#     209                       input_names=input_names, output_names=output_names)
#     210
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/onnx/utils.py in export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, custom_opsets, export_modules_as_functions)
#     502     """
#     503
# --> 504     _export(
#     505         model,
#     506         args,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/onnx/utils.py in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, opset_version, do_constant_folding, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, onnx_shape_inference, export_modules_as_functions)
#    1527             _validate_dynamic_axes(dynamic_axes, model, input_names, output_names)
#    1528
# -> 1529             graph, params_dict, torch_out = _model_to_graph(
#    1530                 model,
#    1531                 args,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/onnx/utils.py in _model_to_graph(model, args, verbose, input_names, output_names, operator_export_type, do_constant_folding, _disable_torch_constant_prop, fixed_batch_size, training, dynamic_axes)
#    1109
#    1110     model = _pre_trace_quant_model(model, args)
# -> 1111     graph, params, torch_out, module = _create_jit_graph(model, args)
#    1112     params_dict = _get_named_param_dict(graph, params)
#    1113
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/onnx/utils.py in _create_jit_graph(model, args)
#     985         return graph, params, torch_out, None
#     986
# --> 987     graph, torch_out = _trace_and_get_graph_from_model(model, args)
#     988     _C._jit_pass_onnx_lint(graph)
#     989     state_dict = torch.jit._unique_state_dict(model)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/onnx/utils.py in _trace_and_get_graph_from_model(model, args)
#     889     prev_autocast_cache_enabled = torch.is_autocast_cache_enabled()
#     890     torch.set_autocast_cache_enabled(False)
# --> 891     trace_graph, torch_out, inputs_states = torch.jit._get_trace_graph(
#     892         model,
#     893         args,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/jit/_trace.py in _get_trace_graph(f, args, kwargs, strict, _force_outplace, return_inputs, _return_inputs_states)
#    1182     if not isinstance(args, tuple):
#    1183         args = (args,)
# -> 1184     outs = ONNXTracedModule(f, strict, _force_outplace, return_inputs, _return_inputs_states)(*args, **kwargs)
#    1185     return outs
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/jit/_trace.py in forward(self, *args)
#     125                 return tuple(out_vars)
#     126
# --> 127         graph, out = torch._C._create_graph_by_tracing(
#     128             wrapper,
#     129             in_vars + module_state,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/jit/_trace.py in wrapper(*args)
#     116             if self._return_inputs_states:
#     117                 inputs_states.append(_unflatten(in_args, in_desc))
# --> 118             outs.append(self.inner(*trace_inputs))
#     119             if self._return_inputs_states:
#     120                 inputs_states[0] = (inputs_states[0], trace_inputs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _slow_forward(self, *input, **kwargs)
#    1180                 recording_scopes = False
#    1181         try:
# -> 1182             result = self.forward(*input, **kwargs)
#    1183         finally:
#    1184             if recording_scopes:
#
# ~/PERSONAL/bb/notebooks/BaseTextDetectorModel.py in forward(self, x, targets, lengths)
#     138
#     139     def forward(self, x, targets=None, lengths=None):
# --> 140         bs, c, w, h = x.size()
#     141         # print(x.shape, 0)
#     142         x = self.conv1(x)
#
# AttributeError: 'list' object has no attribute 'size'
