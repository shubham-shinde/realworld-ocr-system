# %%
import torch
import random
import json
from torch import nn
import cv2
import string as STR
import matplotlib.pyplot as plt

# %%
import importlib

import BaseTextDetectorModel
importlib.reload(BaseTextDetectorModel)
# Out:
# <module 'BaseTextDetectorModel' from '/Users/tnluser/PERSONAL/bb/notebooks/BaseTextDetectorModel.py'>

# %%
dataset = BaseTextDetectorModel.ImageTextDataset(10)

# %%
dataset[0][0].shape
# Out:
# torch.Size([1, 32, 128])

# %%
letters = STR.ascii_letters + STR.digits
letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %%
letters[5]
# Out:
# 'f'

# %%
dataset[0][1]
# Out:
# tensor([29, 34, 27, 39, 27, 31, 29, 51, 42, 27])

# %%
from BaseTextDetectorModel import BaseTextDetector

# %%
model = torch.load('BaseTextDetector.pt',map_location=torch.device('cpu')).eval()

# %%
for i in range(len(dataset)):
    data = dataset[i]
    plt.imshow(data[0].transpose(0, 2).transpose(0, 1))
    plt.show()
    print(data[0].mean(), data[0].std())
    print(data[1])
    print(data[2])
    print(BaseTextDetectorModel.model_text(data[1]))
    model_out, _ = model(data[0][None, ...])
    model_out = model_out.squeeze().detach()
    print(BaseTextDetectorModel.model_text(model_out.detach(), max_needed=True))
# Out:
# tensor(0.0413) tensor(0.1989)
# tensor([54, 53, 59, 57, 55, 60,  0,  0,  0,  0])
# 6
# 106427....
# 10.6.4..2..7...................
# tensor(0.0151) tensor(0.1221)
# tensor([54, 54, 55,  0,  0,  0,  0,  0,  0,  0])
# 3
# 112.......
# 1.12...........................
# tensor(0.0603) tensor(0.2381)
# tensor([19, 20,  1, 14,  4,  1, 18,  4, 23,  9])
# 10
# standardwi
# stan..d..a..r.d..y.ii..........
# tensor(0.0806) tensor(0.2722)
# tensor([45, 47, 28, 32, 41, 47, 40, 30, 27, 46])
# 10
# SUBFOUNDAT
# SUE..R..O...U..N..D..A..T......
# tensor(0.0527) tensor(0.2235)
# tensor([21, 14,  1, 21, 20,  8, 15, 18,  9, 26])
# 10
# unauthoriz
# una..u..t.h.o..r.iz............
# tensor(0.0615) tensor(0.2403)
# tensor([21, 14, 15,  6,  6,  5, 14,  4,  1,  2])
# 10
# unoffendab
# uno..f.fe..n..d..a..b..........
# tensor(0.0540) tensor(0.2260)
# tensor([14,  9,  2,  2, 12,  9, 14,  7, 12, 25])
# 10
# nibblingly
# nibb.l.iinng..ly...............
# tensor(0.0486) tensor(0.2150)
# tensor([ 1,  3, 60, 18,  5, 19, 56,  5,  0,  0])
# 8
# ac7res3e..
# ao7..r.e.s..3..e...............
# tensor(0.0786) tensor(0.2692)
# tensor([29, 41, 31, 39, 42, 31, 44, 41, 44,  0])
# 9
# COEMPEROR.
# COE..M...P..E..R..O..R.........
# tensor(0.0728) tensor(0.2598)
# tensor([46, 44, 27, 29, 31, 38, 31, 45, 45, 38])
# 10
# TRACELESSL
# TRAAO..E..LL.E..S..S..L........

# %%
def test_on_data():
    data = dataset[0]
    # plt.imshow(data[0].transpose(0, 2).transpose(0, 1))
    img = data[0][None, :]
    out = model(img)
    print(model_text(data[1]), model_text(out.squeeze()))
    # plt.show()
for i in range(100): test_on_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cn/9kqyl3fn4dxdrx0sql6q9vlm0000gp/T/ipykernel_88557/2775239232.py in <module>
#       6     print(model_text(data[1]), model_text(out.squeeze()))
#       7     # plt.show()
# ----> 8 for i in range(100): test_on_data()
#
# /var/folders/cn/9kqyl3fn4dxdrx0sql6q9vlm0000gp/T/ipykernel_88557/2775239232.py in test_on_data()
#       4     img = data[0][None, :]
#       5     out = model(img)
# ----> 6     print(model_text(data[1]), model_text(out.squeeze()))
#       7     # plt.show()
#       8 for i in range(100): test_on_data()
#
# NameError: name 'model_text' is not defined
